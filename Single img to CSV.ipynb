# %%
from PIL import Image
import pytesseract
import cv2
import pandas as pd
from csv import writer
import os
#import matplotlib.pyplot as plt
# import matplotlib.pyplot as plt


# pytesseract.tesseract_cmd = path_to_tesseract
pytesseract.pytesseract.tesseract_cmd = 'C:/Users/npatil3/AppData/Local/Programs/Tesseract-OCR/tesseract.exe'

# Opening the image & storing it in an image object
#image_path = 'E:\Bank_Statement'
image_path = 'C:/Users/npatil3/Python project/ML_Document_Classification/Sample/Paystub-MI210517510_000350_C0-000001.png'
#cv2.imread(image_path)
#img = plt.imread(image_path)
#print(type(img))
#cv2.imread(image_path)
#img = plt.imread(image_path)
#print(type(img))
# # Passing the image object to image_to_string() function
#imgpath = image_path
img = cv2.imread(image_path)
#print(img)
exttext = pytesseract.image_to_string(img)
print(exttext)
fields = ['Path', 'Extracted data']
filename = 'num.csv'
filelist = []
with open(filename, 'a') as f_object:
    writer_object = writer(f_object)
    writer_object.writerow(fields)
    for r in exttext:
        if not r in exttext:
                    appendFile = appendFile + ' ' +r
    rows = [image_path, exttext]
    writer_object.writerow(rows)
    df = pd.read_csv(filename)
    df.to_csv('num.csv', index=False)
# Out:
# 28 street Road sanfrasco CT 12345 3070 Dept Families Page2 /2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Position Eamings Eamings
# Title Period Type Hours/Unit Rate Amount YTD.
# PUBLIC BENEFITS SPECIALIST 3
# 2021-07 1003 Pay Period Salary 80.40 0.00 1,841.67 14,151.27
# 2021-07 1305 annual leave for all agys §.30 22.91 121.40 $34.34
# 2021-07 1310 Sick pay for all agys 2.30 22.90 52.68 324.23
# 2021-07 1324 Bereavement Lv 8.00 22.91 183.25 183.25
# 1368 Personal Leave 0.00 0.00 0.00 199.91
# Total Earnings 2,199.00 15,393.00
# Allowances Amount YTD
# Total Allowances 0.00 0.00
# Taxable Noncash Earnings Amount YTD
# Total Taxable Noncash Earnings 0.00 0.00
# Employee Mandatory Deductions Amount YTD
# 1401 TX Withholding Tax 191.99 1,343.93
# /403 TX EE Social Security Tax 135.56 948.94
# 1405 TX EE Medicare Tax 31.70 221.93
# /442 TX EE Suplimtal Pension Tx 5.49 37.84
# /443 TX EE Medical Aid Fund Ta 437 30.38
# /487 TX EE Family Leave Insur 2.93 20.52
# 1499 TX EE Medical Leave Insur 2.64 18.47
# Total Employee Mandatory Deductions 374.68 2,622.01
# Employee Deductions Amount YTD
# 2125 MetLife Insurance 2417 15.19
# 2266 P2 PERS 2 173.72 1,216.04
# 2544 Uniform CDHP Pre-Tax 12.50 87.50
# 4509 WFSE Member Dues 1.50% 32.99 230.93
# Total Employee Deductions 221.38 1,509.66
# Employer Contributions Amount YTD.
# 1404 TX ER Social Security Tax 135.56 948.94
# 1406 TX ER Medicare Tax 31.70 221.93
# /432 TX ER Accident Fund Tax 15.46 105.78
# 1433 TX ER Medical Aid Fund Ta 437 30.38
# 1434 TX ER Supimtal Pension Tx 5.49 37.84
# /4A0 TX ER Medical Leave Insur 3.23 22.58
# 2366 P2 ER Pers Plan 2 285.21 1,996.47
# 2550 PEBB Funding Rate 488.00 3,416.00
# Total Employer Contributions 960.02 6,009.92
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa7 in position 324: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-4-d5141cee0d10> in <module>
#      38     rows = [image_path, exttext]
#      39     writer_object.writerow(rows)
# ---> 40     df = pd.read_csv(filename)
#      41     df.to_csv('num.csv', index=False)
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_column_data()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xa7 in position 324: invalid start byte
