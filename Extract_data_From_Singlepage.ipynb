# %% [markdown]
# Extracting Data From Single Image

# %%
from PIL import Image
import pytesseract
 
# Include tesseract executable in your path
pytesseract.pytesseract.tesseract_cmd = 'C:/Users/npatil3/AppData/Local/Programs/Tesseract-OCR/tesseract.exe'
 
# Create an image object of PIL library
image = Image.open("C:/Users/npatil3/Python project/Basic_Programs/Images/One.PNG")

 
# pass image into pytesseract module
# pytesseract is trained in many languages
image_to_text = pytesseract.image_to_string(image, lang='eng')
 
# Print the text
print(image_to_text)
# Out:
# Loan Number: 51230000976
#
#
#
# Borrower John serena
#
# This is to certify that thes2fstadfra€E%3 4S5ents related to the purchase and/or financing of the
# referenced property located at is one and the same person as:
#
# John serena
# John serena
#
# John serena
#
# April 30, 2021 ee
# Date John serena
#
#
#
#
#
#
#
# A notary public or other officer completing this certificate verifies only the identity of the individual who signed the
# document to which this certificate is attached, and not the truthfulness, accuracy, or validity of that document.
#
#
#
#
#
# Stateof | CALIFORNIA — js
# Countyof “See ap eA LO ,
# On 4/3 OL before me, bla, _! votenuy Pubs bee
# anotary public, personally appeared GRANT ALLEN COPE, vedtomeon _. basis of satisfactory evidence to be the person(s)
# whose name(s) is/are subscribed to the within instrument and acknowledged to me tha¢h¢/s executed the same inter
# ...

# %%
# Create an image object of PIL library
image = Image.open("C:/Users/npatil3/Python project/Basic_Programs/Images/Two.PNG")

 
# pass image into pytesseract module
# pytesseract is trained in many languages
image_to_text = pytesseract.image_to_string(image, lang='eng')
 
# Print the text
print(image_to_text)
# Out:
# Life
#
# ‘Beethoven was born in Bona" His father's
# harsh discipline and alcoholism made bis
# childhood and adolescence difficult. At the age
# ‘of 1, afer his mother's death, Beethoven
# placed himself tthe head ofthe family, taking
# ‘esponsibility for his two younger brother,
#
# ‘ina series of masterpieces, including the
# ‘Symphony No. 3 in E-lat major op. $5
# (he Eroica, completed 1804), Fidelio, and the
# ‘Symphony No. 6 in C minor ep. 67 (1808)
# ‘These works embody his second period, which
# is called bis heroic style
#
# Around 1810 Beethoven was especially deawn
# to the poet and drama of German wniter
# Johan Wolfsang von Goethe, whom he met ia
# 1812 through the initiative of Goethe's youn
# literary friend Bettina Brentano. Betina's
# sisterin-law Antonia Brentano was probably
#
#
#
# " aimoagh ei act dt fi uncer, Beatoven
# ssa taped on Dever 17,177,
#
#
#
# is impairment gaa pat an endo is pefoming

# %%
# Create an image object of PIL library
image = Image.open("C:/Users/npatil3/Python project/Basic_Programs/Images/Three.PNG")

 
# pass image into pytesseract module
# pytesseract is trained in many languages
image_to_text = pytesseract.image_to_string(image, lang='eng')
 
# Print the text
print(image_to_text)
# Out:
# 1 First Section
#
# Multicols Demo
#
# Overleaf
#
# April 2021
#
# All human things are subject to decay. And when fate summons, Monarchs
#
# must obey.
#
#
#
#
#
#
# Lorem ipsum dolor
# sit amet, consectetuer
# Etiam
#
# lisis sem.
#
# Nullam nec mi et neque
# pharetra sollicitudin.
# Praesent imperdiect mi
# nec ante. Donec ullam-
# corper, felis non sodales
# commodo, lectus velit
# ultrices augue, a dignis-
# sim nibh lectus placerat.
#
# pede. Vivamus nunc
# nunc, molestie ut, ul-
# tricies vel, semper in,
#
#
#
# velit. Ut porttitor. Prae-
# sent in sapien. Lorem
# ipsum dolor sit amet,
# consectetuer — adipiscing
# ¢ Duis fringilla tris-
# tique neque. Sed inter-
# dum libero ut metus.
# Pellentesque placerat.
#
#
#
# Nam rutrum augue a
# leo. Morbi sed elit. sit
# amet ante lobortis sollic-
# itudin. Praesent blandit
# blandit, mauris. Praesent
# lectus tellus, aliquet ali-
# quam, luctus a, egestas
# a, turpis. Mauris lacinia
# lorem sit amet ipsum.
# Nune quis urna dictum
# ...

# %%
# Create an image object of PIL library
image = Image.open("C:/Users/npatil3/Python project/Basic_Programs/Images/Four.PNG")

 
# pass image into pytesseract module
# pytesseract is trained in many languages
image_to_text = pytesseract.image_to_string(image, lang='eng')
 
# Print the text
print(image_to_text)
# Out:
# Chapter 1
# Exploring the page layout
#
# 1 hn chagter we wl tye oa of a
#
# 1.1 Some filer text
#
# Ia, inet itn tering The shaw,
# ow opted tat wi ok Hen pce ee rd th
# ters il tn frmation aly? te no ir
# Sister tare Kt” Nowra! A Md a he
# {88 Gyo oman aon helt, eaten
# ‘ead tipi fh nk. Th sl oe
# (Sh a a fhe spat a th wn
# ‘ce ngage Toe tl rn elite, at the
# thf work match othe ng
#
# 1.2. A lot more filler text
# oe nytt wil
#
# 1.2. Plenty of filer text
#
# ow pel et wil ot Ka hice fp rad
# hetero gerne Kt” New aid! A Bnd tt
# {8b gro imation aout the cel et, the ton
# (th a ae fh pat sd sl wit of
# nk aan Th et pent
# Sth cf wet ad match tothe gg, bre aoe
# text wot a meine Ths text sll stor, ow ite
